# %% [markdown]
# # <b>Linear Algebra for CpE

# %% [markdown]
# ### Laboratory 4: Vector Operations

# %% [markdown]
# <h5>Coded and Submitted by:
# <h5><i>Esguerra, Gian Karl J.<i>
# <h5><i>58011<i>

# %% [markdown]
# ### <b>TASK 1<b>

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from numpy.linalg import norm
# %matplotlib inline

# %%
v1 = np.array([5,2,4,8])
v2 = np.array([3,1,2,7])
v3 = np.array([1,9,7,4])
v4 = np.array([7,5,2,6])
v5 = np.array([5,1,3,8])
v6 = np.array([4,3,2,7])

# %%
vec1 = norm(v1)
vec2 = norm(v2)
vec3 = norm(v3)
vec4 = norm(v4)
vec5 = norm(v5)
vec6 = norm(v6)

v_1 = np.linalg.norm(v1)
v_2 = np.linalg.norm(v2)
v_3 = np.linalg.norm(v3)
v_4 = np.linalg.norm(v4)
v_5 = np.linalg.norm(v5)
v_6 = np.linalg.norm(v6)

print('Without using Numpy:', '\n',vec1,'\n',vec2,'\n',vec3,'\n',vec4,'\n',vec5, '\nUsing Numpy:', '\n',v_1,'\n',v_2,'\n',v_3,'\n',v_4,'\n',v_5,)
# Out:
# Without using Numpy:
#  10.44030650891055
#  7.937253933193772
#  12.12435565298214
#  10.677078252031311
#  9.9498743710662
# Using Numpy:
#  10.44030650891055
#  7.937253933193772
#  12.12435565298214
#  10.677078252031311
#  9.9498743710662

# %% [markdown]
# ### <b>TASK 2<b>

# %%
a = np.array([5,2,4,8,2])
b = np.array([3,1,2,7,4])
c = np.array([1,9,7,4,3])
d = np.array([7,5,2,6,7])
e = np.array([5,1,3,8,6])
f = np.array([4,3,2,7,1])
g = np.array([7,3,9,8,2])
h = np.array([6,3,4,8,5])
i = np.array([1,2,5,7,9])
j = np.array([4,2,5,1,6])

# %%
Test1 = a.dot(b)
Test2 = c.dot(d)
Test3 = e.dot(f)
Test4 = g.dot(h)
Test5 = i.dot(j)

Test_1 = np.inner(a,b)
Test_2 = np.inner(c,d)
Test_3 = np.inner(e,f)
Test_4 = np.inner(g,h)
Test_5 = np.inner(i,j)

print('Without using Numpy:', '\n',Test1,'\n',Test2,'\n',Test3,'\n',Test4,'\n',Test5, '\nUsing Numpy:', '\n',Test_1,'\n',Test_2,'\n',Test_3,'\n',Test_4,'\n',Test_5)
# Out:
# Without using Numpy:
#  89
#  111
#  91
#  161
#  94
# Using Numpy:
#  89
#  111
#  91
#  161
#  94

# %% [markdown]
# ### <b>TASK 3<b>

# %% [markdown]
# $$ $$$$A = \begin{bmatrix}-1\\0.3\\-0.8\end{bmatrix}, B = \begin{bmatrix}-0.7\\0.1\\0.5\end{bmatrix}, C = \begin{bmatrix}0.2\\0.1\\-0.9\end{bmatrix}$$

# %%
v_A = np.array([-1,0.3,-0.8])
v_B = np.array([-0.7,0.1,0.5])
v_C = np.array([0.2,0.1,-0.9])

X = ((v_A**2+v_B**2+v_C**2)@(v_A*(v_B+v_A*v_B)/v_C))*(np.absolute(v_A))+(np.absolute(v_B))
Y = v_A**2+v_B**2
Z = (v_A)
X = (v_A@v_A + v_B@v_B + v_C@v_C)
X1 = (v_A*(v_B+v_A*v_B)/v_C)
X2 = (np.linalg.norm(v_A+v_B+v_C))
Ans = X*X1*X2

np.array(Ans)
# Out:
# array([-0.        ,  2.58558717,  0.58930762])

# %%
plot = plt.figure()
a1 = plot.gca(projection = '3d')

a1.quiver(0,0,0, Ans[0], Ans[1], Ans[2], color = 'blue')
a1.set_xlim([0,3])
a1.set_ylim([0,3])
a1.set_zlim([0,3])
plt.show()
